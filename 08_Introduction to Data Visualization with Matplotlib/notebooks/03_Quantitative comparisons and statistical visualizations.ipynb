# %% [markdown]
# # Quantitative comparisons and statistical visualizations

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
medals = pd.read_csv('../data/medals_by_country_2016.csv', index_col='Unnamed: 0')
medals.sample(2)
# Out:
#         Bronze  Gold  Silver
# Russia      35    50      28
# Italy       24     8      38

# %%
mens_rowing = pd.read_csv('../data/mens_rowing.csv', index_col=0)
mens_rowing.sample(2)
# Out:
#        Unnamed: 0      ID                           Name Sex   Age  Height  \
# 7100       142874   71687  Constantine Michael Louloudis   M  24.0   190.0
# 10728      213343  107131                Richard Schmidt   M  29.0   191.0
#
#        Weight           Team  NOC        Games  Year  Season            City  \
# 7100     92.0  Great Britain  GBR  2016 Summer  2016  Summer  Rio de Janeiro
# 10728    87.0        Germany  GER  2016 Summer  2016  Summer  Rio de Janeiro
#
#         Sport                       Event   Medal
# 7100   Rowing  Rowing Men's Coxless Fours    Gold
# 10728  Rowing   Rowing Men's Coxed Eights  Silver

# %%
mens_gymnastics = pd.read_csv('../data/mens_gymnastics.csv', index_col=0)
mens_gymnastics.sample(2)
# Out:
#        Unnamed: 0      ID                 Name Sex   Age  Height  Weight  \
# 13054      259835  130071  Max Antony Whitlock   M  23.0   167.0    56.0
# 6990       140788   70677             Liu Yang   M  21.0   162.0    61.0
#
#                 Team  NOC        Games  Year  Season            City  \
# 13054  Great Britain  GBR  2016 Summer  2016  Summer  Rio de Janeiro
# 6990           China  CHN  2016 Summer  2016  Summer  Rio de Janeiro
#
#             Sport                             Event   Medal
# 13054  Gymnastics  Gymnastics Men's Pommelled Horse    Gold
# 6990   Gymnastics  Gymnastics Men's Team All-Around  Bronze

# %%
seattle_weather = pd.read_csv('../data/seattle_weather.csv', index_col=0)
seattle_weather.sample(2)
# Out:
#           STATION                         NAME  MLY-CLDD-BASE45  \
# DATE
# 10    USW00094290  SEATTLE SAND PT WSFO, WA US            260.0
# 1     USW00094290  SEATTLE SAND PT WSFO, WA US             27.0
#
#       MLY-CLDD-BASE50  MLY-CLDD-BASE55  MLY-CLDD-BASE57  MLY-CLDD-BASE60  \
# DATE
# 10              123.0             35.0             17.0              4.0
# 1                 3.0          -7777.0          -7777.0              0.0
#
#       MLY-CLDD-BASE70  MLY-CLDD-BASE72  MLY-CLDD-NORMAL  ...  \
# DATE                                                     ...
# 10            -7777.0              0.0          -7777.0  ...
# 1                 0.0              0.0              0.0  ...
#
#       MLY-TMIN-AVGNDS-LSTH070  MLY-TMIN-NORMAL  MLY-TMIN-PRBOCC-LSTH016  \
# DATE
# 10                      310.0             46.5                      0.0
# 1                       310.0             37.0                     64.0
#
#       MLY-TMIN-PRBOCC-LSTH020  MLY-TMIN-PRBOCC-LSTH024  \
# DATE
# 10                        0.0                      0.0
# 1                       129.0                    317.0
#
#       MLY-TMIN-PRBOCC-LSTH028  MLY-TMIN-PRBOCC-LSTH032  \
# DATE
# 10                        2.0                     58.0
# 1                       709.0                    959.0
#
#       MLY-TMIN-PRBOCC-LSTH036  MLY-TMIN-STDDEV  MONTH
# DATE
# 10                      349.0              1.8    Oct
# 1                      1000.0              2.3    Jan
#
# [2 rows x 80 columns]

# %%
austin_weather = pd.read_csv('../data/austin_weather.csv', index_col=0)
austin_weather.sample(2)
# Out:
#           STATION                                           NAME  \
# DATE
# 11    USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 6     USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
#
#       MLY-CLDD-BASE45  MLY-CLDD-BASE50  MLY-CLDD-BASE55  MLY-CLDD-BASE57  \
# DATE
# 11                412              281              172              136
# 6                1081              931              781              721
#
#       MLY-CLDD-BASE60  MLY-CLDD-BASE70  MLY-CLDD-BASE72  MLY-CLDD-NORMAL  ...  \
# DATE                                                                      ...
# 11                 91               12                7               38  ...
# 6                 631              331              272              481  ...
#
#       MLY-TMIN-AVGNDS-LSTH070  MLY-TMIN-NORMAL  MLY-TMIN-PRBOCC-LSTH016  \
# DATE
# 11                        297             45.5                        2
# 6                         158             69.9                        0
#
#       MLY-TMIN-PRBOCC-LSTH020  MLY-TMIN-PRBOCC-LSTH024  \
# DATE
# 11                         46                      216
# 6                           0                        0
#
#       MLY-TMIN-PRBOCC-LSTH028  MLY-TMIN-PRBOCC-LSTH032  \
# DATE
# 11                        530                      819
# 6                           0                        0
#
#       MLY-TMIN-PRBOCC-LSTH036  MLY-TMIN-STDDEV  MONTH
# DATE
# 11                        969              2.9    Nov
# 6                           0              1.9    Jun
#
# [2 rows x 67 columns]

# %%
climate_change = pd.read_csv('../data/climate_change.csv', index_col=0, parse_dates=['date'])
climate_change.sample(2)
# Out:
#                co2  relative_temp
# date
# 1981-04-06  342.53           0.32
# 2015-10-06  398.29           1.06

# %% [markdown]
# ## Quantitative comparisons: bar-charts

# %% [markdown]
# ### Bar chart

# %%
fig, ax = plt.subplots()

# Plot a bar-chart of gold medals as a function of country
ax.bar(medals.index, medals['Gold'])

# Set the x-axis tick labels to the country names
ax.set_xticklabels(medals.index, rotation=90)

# Set the y-axis label
ax.set_ylabel('Number of medals')

plt.show()
# Out:
# C:\Users\RamirezIA\AppData\Local\Temp\ipykernel_29104\2728011017.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medals.index, rotation=90)

# %% [markdown]
# ### Stacked bar chart

# %%
fig, ax = plt.subplots()

# Add bars for "Gold" with the label "Gold"
ax.bar(medals.index, medals['Gold'], label='Gold')

# Stack bars for "Silver" on top with label "Silver"
ax.bar(medals.index, medals['Silver'], bottom=medals['Gold'], label='Silver')

# Stack bars for "Bronze" on top of that with label "Bronze"
ax.bar(medals.index, medals['Bronze'], bottom=medals['Gold'] + medals['Silver'], label='Bronze')

# Display the legend
ax.legend()

plt.show()

# %% [markdown]
# ## Quantitative comparisons: histograms

# %% [markdown]
# ### Creating histograms

# %%
fig, ax = plt.subplots()
# Plot a histogram of "Weight" for mens_rowing
ax.hist(mens_rowing['Weight'])

# Compare to histogram of "Weight" for mens_gymnastics
ax.hist(mens_gymnastics['Weight'])

# Set the x-axis label to "Weight (kg)"
ax.set_xlabel('Weight (kg)')

# # Set the y-axis label to "# of observations"
ax.set_ylabel('# of observations')

plt.show()

# %% [markdown]
# ### "Step" histogram

# %%
fig, ax = plt.subplots()

# Plot a histogram of "Weight" for mens_rowing
ax.hist(mens_rowing['Weight'], label='Rowing', histtype='step', bins=5)

# Compare to histogram of "Weight" for mens_gymnastics
ax.hist(mens_gymnastics['Weight'], label='Gymnastics', histtype='step', bins=5)

ax.set_xlabel("Weight (kg)")
ax.set_ylabel("# of observations")

# Add the legend and show the Figure
ax.legend()

plt.show()

# %% [markdown]
# ## Statistical plotting

# %% [markdown]
# ### Adding error-bars to a bar chart

# %%
fig, ax = plt.subplots()

# Add a bar for the rowing "Height" column mean/std
ax.bar("Rowing", mens_rowing['Height'].mean(), yerr=mens_rowing['Height'].std())

# Add a bar for the gymnastics "Height" column mean/std
ax.bar("Gymnastics", mens_gymnastics['Height'].mean(), yerr=mens_gymnastics['Height'].std())

# Label the y-axis
ax.set_ylabel('Height (cm)')

plt.show()

# %% [markdown]
# ### Adding error-bars to a plot

# %%
fig, ax = plt.subplots()

# Add Seattle temperature data in each month with error bars
ax.errorbar(seattle_weather['MONTH'], seattle_weather['MLY-TAVG-NORMAL'], yerr=seattle_weather['MLY-TAVG-STDDEV'])

# Add Austin temperature data in each month with error bars
ax.errorbar(austin_weather['MONTH'], austin_weather['MLY-TAVG-NORMAL'], yerr=austin_weather['MLY-TAVG-STDDEV'])

# Set the y-axis label
ax.set_ylabel('Temperature (Fahrenheit)')

plt.show()

# %% [markdown]
# ### Creating boxplots

# %%
fig, ax = plt.subplots()

# Add a boxplot for the "Height" column in the DataFrames
ax.boxplot([mens_rowing["Height"],
mens_gymnastics["Height"]])

# Add x-axis tick labels:
ax.set_xticklabels(["Rowing", "Gymnastics"])

# Add a y-axis label
ax.set_ylabel("Height (cm)")

plt.show()

# %% [markdown]
# ## Quantitative comparisons: scatter plots

# %% [markdown]
# ### Simple scatter plot

# %%
fig, ax = plt.subplots()

# Add data: "co2" on x-axis, "relative_temp" on y-axis
ax.scatter(climate_change['co2'], climate_change['relative_temp'])

# Set the x-axis label to "CO2 (ppm)"
ax.set_xlabel("CO2 (ppm)")

# Set the y-axis label to "Relative temperature (C)"
ax.set_ylabel("Relative temperature (C)")

plt.show()

# %% [markdown]
# ### Encoding time by color

# %%
fig, ax = plt.subplots()

# Add data: "co2", "relative_temp" as x-y, index as color
ax.scatter(climate_change['co2'], climate_change['relative_temp'], c=climate_change.index)

# Set the x-axis label to "CO2 (ppm)"
ax.set_xlabel("CO2 (ppm)")

# Set the y-axis label to "Relative temperature (C)"
ax.set_ylabel("Relative temperature (C)")

plt.show()
