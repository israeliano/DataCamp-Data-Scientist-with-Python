# %% [markdown]
# # Clustering for Dataset Exploration

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Unsupervised Learning

# %% [markdown]
# ### Clustering 2D points

# %%
points = np.array([[ 0.06544649, -0.76866376],
       [-1.52901547, -0.42953079],
       [ 1.70993371,  0.69885253],
       [ 1.16779145,  1.01262638],
       [-1.80110088, -0.31861296],
       [-1.63567888, -0.02859535],
       [ 1.21990375,  0.74643463],
       [-0.26175155, -0.62492939],
       [-1.61925804, -0.47983949],
       [-1.84329582, -0.16694431],
       [ 1.35999602,  0.94995827],
       [ 0.42291856, -0.7349534 ],
]
)

new_points = np.array([[ 4.00233332e-01, -1.26544471e+00],
       [ 8.03230370e-01,  1.28260167e+00],
       [-1.39507552e+00,  5.57292921e-02],
       [-3.41192677e-01, -1.07661994e+00],
       [ 1.54781747e+00,  1.40250049e+00],
       [ 2.45032018e-01, -4.83442328e-01],
       [ 1.20706886e+00,  8.88752605e-01],
       [ 1.25132628e+00,  1.15555395e+00],
       [ 1.81004415e+00,  9.65530731e-01],
       [-1.66963401e+00, -3.08103509e-01],
       [-7.17482105e-02, -9.37939700e-01],])

# %%
# Import KMeans
from sklearn.cluster import KMeans

# Create a KMeans instance with 3 clusters: model
model = KMeans(n_clusters=3)

# Fit model to points
model.fit(points)

# Determine the cluster labels of new_points: labels
labels = model.predict(new_points)

# Print cluster labels of new_points
print(labels)
# Out:
# [2 1 0 2 1 2 1 1 1 0 2]

# %% [markdown]
# ### Inspect your clustering

# %%
# Import pyplot
import matplotlib.pyplot as plt

# Assign the columns of new_points: xs and ys
xs = new_points[:, 0]
ys = new_points[:, 1]

# Make a scatter plot of xs and ys, using labels to define the colors
plt.scatter(x=xs, y=ys, c=labels, alpha=0.5)

# Assign the cluster centers: centroids
centroids = model.cluster_centers_

# Assign the columns of centroids: centroids_x, centroids_y
centroids_x = centroids[:,0]
centroids_y = centroids[:,1]

# Make a scatter plot of centroids_x and centroids_y
plt.scatter(x=centroids_x, y=centroids_y, marker='D', s=50)
plt.show()

# %% [markdown]
# ## Evaluating a clustering

# %% [markdown]
# ### How many clusters of grain?

# %%
samples = pd.read_csv('seeds.csv', header=None).iloc[:, :-2]

# %%
ks = range(1, 6)
inertias = []

for k in ks:
    # Create a KMeans instance with k clusters: model
    model = KMeans(n_clusters=k)
    
    # Fit model to samples
    model.fit(samples)
    
    # Append the inertia to the list of inertias
    inertias.append(model.inertia_)
    
# Plot ks vs inertias
plt.plot(ks, inertias, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()

# %% [markdown]
# ### Evaluating the grain clustering

# %%
varieties = pd.read_csv('seeds.csv', header=None).iloc[:, -1].replace({1: 'Kama wheat', 2: 'Rosa wheat', 3: 'Canadian wheat'})

# %%
# Create a KMeans model with 3 clusters: model
model = KMeans(n_clusters=3)

# Use fit_predict to fit model and obtain cluster labels: labels
labels = model.fit(samples).labels_

# Create a DataFrame with labels and varieties as columns: df
df = pd.DataFrame({'labels': labels, 'varieties': varieties})

# Create crosstab: ct
ct = pd.crosstab(df['labels'], df['varieties'])

# Display ct
print(ct)
# Out:
# varieties  Canadian wheat  Kama wheat  Rosa wheat
# labels
# 0                      68           9           0
# 1                       0           1          60
# 2                       2          60          10

# %% [markdown]
# ## Transforming features for better clusterings

# %%
samples = pd.read_csv('fish.csv', header=None).iloc[:, 1:]
species = pd.read_csv('fish.csv', header=None).iloc[:, 0]

# %% [markdown]
# ### Scaling fish data for clustering

# %%
# Perform the necessary imports
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Create scaler: scaler
scaler = StandardScaler()

# Create KMeans instance: kmeans
kmeans = KMeans(n_clusters=4)

# Create pipeline: pipeline
pipeline = make_pipeline(scaler, kmeans)

# %% [markdown]
# ### Clustering the fish data

# %%
# Import pandas
import pandas as pd

# Fit the pipeline to samples
pipeline.fit(samples)

# Calculate the cluster labels: labels
labels = pipeline.predict(samples)

# Create a DataFrame with labels and species as columns: df
df = pd.DataFrame({'labels': labels, 'species': species})

# Create crosstab: ct
ct = pd.crosstab(df['labels'], df['species'])

# Display ct
print(ct)
# Out:
# species  Bream  Pike  Roach  Smelt
# labels
# 0            3     0     20      0
# 1            0     0      0     14
# 2            0    17      0      0
# 3           31     0      0      0

# %% [markdown]
# ### Clustering stocks using KMeans

# %%
movements = pd.read_csv('company-stock-movements-2010-2015-incl.csv').iloc[:, 1:]
companies = pd.read_csv('company-stock-movements-2010-2015-incl.csv').iloc[:, 0]

# %%
# Import Normalizer
from sklearn.preprocessing import Normalizer

# Create a normalizer: normalizer
normalizer = Normalizer()

# Create a KMeans model with 10 clusters: kmeans
kmeans = KMeans(n_clusters=10)

# Make a pipeline chaining normalizer and kmeans: pipeline
pipeline = make_pipeline(normalizer, kmeans)

# Fit pipeline to the daily price movements
pipeline.fit(movements)
# Out:
# Pipeline(steps=[('normalizer', Normalizer()),
#                 ('kmeans', KMeans(n_clusters=10))])

# %% [markdown]
# ### Which stocks move together?

# %%
# Import pandas
import pandas as pd

# Predict the cluster labels: labels
labels = pipeline.predict(movements)

# Create a DataFrame aligning labels and companies: df
df = pd.DataFrame({'labels': labels, 'companies': companies})

# Display df sorted by cluster label
print(df.sort_values(by='labels'))
# Out:
#     labels                           companies
# 16       0                   General Electrics
# 58       0                               Xerox
# 56       1                            Wal-Mart
# 27       1                      Kimberly-Clark
# 40       1                      Procter Gamble
# 9        1                   Colgate-Palmolive
# 25       1                   Johnson & Johnson
# 37       2                            Novartis
# 39       2                              Pfizer
# 52       2                            Unilever
# 6        2            British American Tobacco
# 19       2                     GlaxoSmithKline
# 46       2                      Sanofi-Aventis
# 22       3                                  HP
# 21       3                               Honda
# 45       3                                Sony
# 34       3                          Mitsubishi
# 48       3                              Toyota
# 7        3                               Canon
# 10       4                      ConocoPhillips
# 49       4                               Total
# 44       4                        Schlumberger
# 12       4                             Chevron
# 43       4                                 SAP
# 42       4                   Royal Dutch Shell
# 57       4                               Exxon
# 53       4                       Valero Energy
# 36       5                    Northrop Grumman
# 29       5                     Lookheed Martin
# 54       6                            Walgreen
# 35       6                            Navistar
# 50       6  Taiwan Semiconductor Manufacturing
# 51       6                   Texas instruments
# 47       6                            Symantec
# 59       6                               Yahoo
# 32       6                                  3M
# 30       6                          MasterCard
# 4        6                              Boeing
# 24       6                               Intel
# 23       6                                 IBM
# 20       6                          Home Depot
# 8        6                         Caterpillar
# 11       6                               Cisco
# 33       6                           Microsoft
# 14       6                                Dell
# 13       6                   DuPont de Nemours
# 1        7                                 AIG
# 55       7                         Wells Fargo
# 3        7                    American express
# 5        7                     Bank of America
# 15       7                                Ford
# 18       7                       Goldman Sachs
# 26       7                      JPMorgan Chase
# 2        8                              Amazon
# 17       8                     Google/Alphabet
# 0        8                               Apple
# 41       9                       Philip Morris
# 28       9                           Coca Cola
# 38       9                               Pepsi
# 31       9                           McDonalds
