# %% [markdown]
# # Customizing Seaborn Plots

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
survey_data = pd.read_csv('../data/young-people-survey-responses.csv', index_col=0)
survey_data.sample(2)
# Out:
#      Music  Techno  Movies  History  Mathematics  Pets  Spiders  Loneliness  \
# 300    5.0     1.0     3.0      3.0          3.0   2.0      1.0         2.0
# 685    5.0     3.0     5.0      3.0          2.0   5.0      4.0         4.0
#
#      Parents' advice   Internet usage  Finances   Age  Siblings  Gender  \
# 300              3.0  most of the day       4.0  18.0       1.0  female
# 685              4.0  few hours a day       3.0  19.0       0.0  female
#
#     Village - town
# 300           city
# 685        village

# %%
mpg = pd.read_csv('../data/mpg.csv')
mpg.sample(2)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 226  20.5          6         231.0       105.0    3425          16.9
# 155  15.0          6         250.0        72.0    3158          19.5
#
#      model_year origin           name
# 226          77    usa  buick skylark
# 155          75    usa  ford maverick

# %% [markdown]
# ## Changing plot style and color

# %% [markdown]
# ### Changing style and palette

# %%
survey_data['Parents Advice'] = survey_data["Parents' advice"].map(
    {1: 'Never', 2: 'Rarely', 3: 'Sometimes', 4: 'Often', 5: 'Always'}
)

# %%
# Set the style to "whitegrid"
sns.set_style('whitegrid')


# Create a count plot of survey responses
category_order = ["Never", "Rarely", "Sometimes", 
                  "Often", "Always"]

sns.catplot(x="Parents Advice", 
            data=survey_data, 
            kind="count", 
            order=category_order)

# Show plot
plt.show()

# %%
# Set the color palette to "Purples"
sns.set_style("whitegrid")
sns.set_palette('PRGn')

# Create a count plot of survey responses
category_order = ["Never", "Rarely", "Sometimes", 
                  "Often", "Always"]

sns.catplot(x="Parents Advice", 
            data=survey_data, 
            kind="count", 
            order=category_order)

# Show plot
plt.show()

# %%
# Change the color palette to "RdBu"
sns.set_style("whitegrid")
sns.set_palette("RdBu")

# Create a count plot of survey responses
category_order = ["Never", "Rarely", "Sometimes", 
                  "Often", "Always"]

sns.catplot(x="Parents Advice", 
            data=survey_data, 
            kind="count", 
            order=category_order)

# Show plot
plt.show()

# %% [markdown]
# ### Changing the scale

# %%
survey_data['Number of Siblings'] = survey_data['Siblings']

# %%
# Set the context to "paper"
sns.set_context('paper')

# Create bar plot
sns.catplot(x="Number of Siblings", y="Feels Lonely",
            data=survey_data, kind="bar")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 5
#       2 sns.set_context('paper')
#       4 # Create bar plot
# ----> 5 sns.catplot(x="Number of Siblings", y="Feels Lonely",
#       6             data=survey_data, kind="bar")
#       8 # Show plot
#       9 plt.show()
#
# File ~/miniconda3/envs/ds1/lib/python3.11/site-packages/seaborn/categorical.py:3187, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3185 p = _CategoricalPlotter()
#    3186 p.require_numeric = plotter_class.require_numeric
# -> 3187 p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3188 if (
#    3189     order is not None
#    3190     or (sharex and p.orient == "v")
#    3191     or (sharey and p.orient == "h")
#    3192 ):
#    3193     # Sync categorical axis between facets to have the same categories
#    3194     order = p.group_names
#
# File ~/miniconda3/envs/ds1/lib/python3.11/site-packages/seaborn/categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'Feels Lonely'

# %%
# Change the context to "notebook"
sns.set_context("notebook")

# Create bar plot
sns.catplot(x="Number of Siblings", y="Feels Lonely",
            data=survey_data, kind="bar")

# Show plot
plt.show()

# %%
# Change the context to "talk"
sns.set_context("talk")

# Create bar plot
sns.catplot(x="Number of Siblings", y="Feels Lonely",
            data=survey_data, kind="bar")

# Show plot
plt.show()

# %%
# Change the context to "poster"
sns.set_context("poster")

# Create bar plot
sns.catplot(x="Number of Siblings", y="Feels Lonely",
            data=survey_data, kind="bar")

# Show plot
plt.show()

# %% [markdown]
# ### Using a custom palette

# %%
# Set the style to "darkgrid"
sns.set_style('darkgrid')

# Set a custom color palette
custom_palette = ["#39A7D0", "#36ADA4"]
sns.set_palette(custom_palette)

# Create the box plot of age distribution by gender
sns.catplot(x="Gender", y="Age", 
            data=survey_data, kind="box")

# Show plot
plt.show()

# %% [markdown]
# ## Adding titles and labels: Part 1

# %% [markdown]
# ### FacetGrids vs. AxesSubplots

# %%
# Create scatter plot
g = sns.relplot(x="weight", 
                y="horsepower", 
                data=mpg,
                kind="scatter")

# Identify plot type
type_of_g = type(g)

# Print type
print(type_of_g)
# Out:
# <class 'seaborn.axisgrid.FacetGrid'>

# %% [markdown]
# ### Adding a title to a FacetGrid object

# %%
# Create scatter plot
g = sns.relplot(x="weight", 
                y="horsepower", 
                data=mpg,
                kind="scatter")

# Add a title "Car Weight vs. Horsepower"
g.fig.suptitle("Car Weight vs. Horsepower")

# Show plot
plt.show()

# %% [markdown]
# ## Adding titles and labels: Part 2

# %% [markdown]
# ### Adding a title and axis labels

# %%
# Create line plot
g = sns.lineplot(x="model_year", y="mpg_mean", 
                 data=mpg_mean,
                 hue="origin")

# Add a title "Average MPG Over Time"
g.set_title("Average MPG Over Time")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 # Create line plot
#       2 g = sns.lineplot(x="model_year", y="mpg_mean",
# ----> 3                  data=mpg_mean,
#       4                  hue="origin")
#       6 # Add a title "Average MPG Over Time"
#       7 g.set_title("Average MPG Over Time")
#
# NameError: name 'mpg_mean' is not defined

# %%
# Create line plot
g = sns.lineplot(x="model_year", y="mpg_mean", 
                 data=mpg_mean,
                 hue="origin")

# Add a title "Average MPG Over Time"
g.set_title("Average MPG Over Time")

# Add x-axis and y-axis labels
g.set(xlabel="Car Model Year",
ylabel="Average MPG")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 # Create line plot
#       2 g = sns.lineplot(x="model_year", y="mpg_mean",
# ----> 3                  data=mpg_mean,
#       4                  hue="origin")
#       6 # Add a title "Average MPG Over Time"
#       7 g.set_title("Average MPG Over Time")
#
# NameError: name 'mpg_mean' is not defined

# %% [markdown]
# ### Rotating x-tick labels

# %%
# Create point plot
sns.catplot(x="origin", 
            y="acceleration", 
            data=mpg, 
            kind="point", 
            join=False, 
            capsize=0.1)

# Rotate x-tick labels
plt.xticks(rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ## Putting it all together

# %% [markdown]
# ### Box plot with subgroups

# %%
# Set palette to "Blues"
sns.set_palette('Blues')

# Adjust to add subgroups based on "Interested in Pets"
g = sns.catplot(x="Gender",
                y="Age", data=survey_data, 
                kind="box", hue='Interested in Pets')

# Set title to "Age of Those Interested in Pets vs. Not"
g.fig.suptitle('Age of Those Interested in Pets vs. Not')

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 5
#       2 sns.set_palette('Blues')
#       4 # Adjust to add subgroups based on "Interested in Pets"
# ----> 5 g = sns.catplot(x="Gender",
#       6                 y="Age", data=survey_data,
#       7                 kind="box", hue='Interested in Pets')
#       9 # Set title to "Age of Those Interested in Pets vs. Not"
#      10 g.fig.suptitle('Age of Those Interested in Pets vs. Not')
#
# File ~/miniconda3/envs/ds1/lib/python3.11/site-packages/seaborn/categorical.py:3187, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3185 p = _CategoricalPlotter()
#    3186 p.require_numeric = plotter_class.require_numeric
# -> 3187 p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3188 if (
#    3189     order is not None
#    3190     or (sharex and p.orient == "v")
#    3191     or (sharey and p.orient == "h")
#    3192 ):
#    3193     # Sync categorical axis between facets to have the same categories
#    3194     order = p.group_names
#
# File ~/miniconda3/envs/ds1/lib/python3.11/site-packages/seaborn/categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'Interested in Pets'

# %% [markdown]
# ### Bar plot with subgroups and subplots

# %%
# Set the figure style to "dark"
sns.set_style('dark')

# Adjust to add subplots per gender
g = sns.catplot(x="Village - town", y="Likes Techno", 
                data=survey_data, kind="bar",
                col='Gender')

# Add title and axis labels
g.fig.suptitle("Percentage of Young People Who Like Techno", y=1.02)
g.set(xlabel="Location of Residence", 
       ylabel="% Who Like Techno")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 5
#       2 sns.set_style('dark')
#       4 # Adjust to add subplots per gender
# ----> 5 g = sns.catplot(x="Village - town", y="Likes Techno",
#       6                 data=survey_data, kind="bar",
#       7                 col='Gender')
#       9 # Add title and axis labels
#      10 g.fig.suptitle("Percentage of Young People Who Like Techno", y=1.02)
#
# File ~/miniconda3/envs/ds1/lib/python3.11/site-packages/seaborn/categorical.py:3187, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3185 p = _CategoricalPlotter()
#    3186 p.require_numeric = plotter_class.require_numeric
# -> 3187 p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3188 if (
#    3189     order is not None
#    3190     or (sharex and p.orient == "v")
#    3191     or (sharey and p.orient == "h")
#    3192 ):
#    3193     # Sync categorical axis between facets to have the same categories
#    3194     order = p.group_names
#
# File ~/miniconda3/envs/ds1/lib/python3.11/site-packages/seaborn/categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'Likes Techno'
